# %%
import numpy as np
import pandas as pd
import math

# %%
term_freq= pd.read_csv("VSMTermFrequency.csv")
term_freq.drop(columns= ["Unnamed: 0"], inplace = True)

# %%
class_freq = pd.read_csv("VSMClassFrequency.csv")
class_freq.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
# %%time
collection_freq = term_freq.sum(axis = 0)
doc_freq = (term_freq > 0).sum(axis = 0)
# Out:
# CPU times: user 5.15 s, sys: 137 ms, total: 5.29 s
# Wall time: 5 s

# %%
# %%time
term_freq = 1 + np.log10(term_freq)
term_freq.replace(to_replace = -np.inf, value = 0, inplace = True)
# Out:
# /home/vedant/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
inv_doc_freq = np.log10(1000/doc_freq)

# %%
df = tf.multiply(inv_doc_freq, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3a8c2575ad18> in <module>
# ----> 1 df = tf.multiply(inv_doc_freq, axis = 1)
#
# NameError: name 'tf' is not defined

# %%
term_freq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-767525084faf> in <module>
# ----> 1 term_freq
#
# NameError: name 'term_freq' is not defined

# %%
df
# Out:
#        golden      rule     boost  chancellor    gordon     brown     given  \
# 0    3.701684  0.916614  1.639368    3.609045  3.635229  3.007296  0.809073
# 1    0.000000  0.000000  1.401869    0.000000  0.000000  0.000000  0.000000
# 2    0.000000  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 3    0.000000  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 5    0.000000  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 6    0.000000  0.000000  1.401869    0.000000  0.000000  0.000000  0.000000
# 7    0.000000  0.830258  1.401869    0.000000  0.000000  0.000000  0.809073
# 8    0.000000  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 9    0.000000  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 10   0.000000  0.000000  1.401869    0.000000  0.000000  0.000000  0.000000
# ...
